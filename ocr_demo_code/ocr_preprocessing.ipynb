# %% [markdown]
# # Pre-processing:
# - Install imgtxtenh following this link: https://github.com/mauvilsa/imgtxtenh
# - Run command: ./imgtxtenh -p [input_image]  [output_image]
#
# # Image segmentation:
#
# Notebook: from beginning to clustering stage
#
# # Image to text:
# Notebook: prediction stage

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
# %cd "/content/drive/My Drive/OCR-PIPELINE/ocr_demo_code/"

# %%
# !rm -rf imgtxtenh
# !git clone https://github.com/mauvilsa/imgtxtenh

# %%
# !dpkg --configure -a

# %%
# !apt install libmagickwand-dev

# %%
# %cd  "./imgtxtenh/"
#!rm CMakeCache.txt
# !cmake CMakeLists.txt -DCMAKE_BUILD_TYPE=Release
# !make

# %%
# !sudo chmod +x ./imgtxtenh
# !./imgtxtenh

# %% [markdown]
# ###Dung lenh !./imgtxtenh test4.jpg -p pre_test4.jpg --> Truyen anh can preprocess vao va dat ten cho anh output

# %%
# !./imgtxtenh 0000_samples.png -p pre_0000_samples.png

# %%
# ! IMAGE PATH
# %cd "../input_data/"

# %%
# !ls | xargs --replace=$ ../imgtxtenh/imgtxtenh $ -p ./pre_$.jpg

# %%
import subprocess
import os
path='/content/drive/My Drive/ocr_demo_code/test_imgs/test'
filesT = os.listdir(path)

p = subprocess.Popen('./imgtxtenh bi_sample2.png -p out1.png', shell=True, stdout=subprocess.PIPE)

# %% [markdown]
# ###Show anh sau khi preprocess

# %%
from IPython.display import Image
Image('pre_0000_samples.png')
